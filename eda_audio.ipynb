# %%
import os
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

# %%
# Importing the audio files.
root = "D:\Rohit\Projects\Capstone Project 2\data"

# %%
wav_files = []
for dirpath, _, files in os.walk(root):
    for f in files:
        if f.endswith('.wav'):
            wav_files.append(os.path.join(dirpath,f))

print("Total wav files:", len(wav_files))
# Out:
# Total wav files: 2880

# %%
# Importing single audio file.
sample = wav_files[0]
print("Sample file:", sample)
# Out:
# Sample file: D:\Rohit\Projects\Capstone Project 2\Dataset\RAVDESS Emotional Speech Audio\Actor_01\03-01-01-01-01-01-01.wav

# %%
# Loading sample using librosa.
y, sr = librosa.load(sample, sr=None) 
print("Sample rate:", sr, "\n" "Samples:", len(y), "\n" "Duration (s):", len(y)/sr)
# Out:
# Sample rate: 48000
# Samples: 158558
# Duration (s): 3.3032916666666665

# %% [markdown]
# ### **Plotting Audio Waveform**

# %%
plt.figure(figsize=(10,2))
librosa.display.waveshow(y, sr=sr)
plt.title("Waveform")
plt.show()

# %% [markdown]
# ### **Plotting Mel Spectrogram**

# %%
S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=64)
S_db = librosa.power_to_db(S, ref=np.max)

plt.figure(figsize=(10,5))
librosa.display.specshow(S_db, sr=sr, x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')
plt.title("Log-mel spectrogram")
plt.show()
